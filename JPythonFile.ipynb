# %%
#installed pip imutils & numpy in cmd
#importing packages:
from imutils import paths 
import cv2

import pandas as pd
import numpy as np

# %%
# !pip install opencv-python

# %%
#loading all image paths
imagePaths = list(paths.list_images(r"C:\Users\Admin\Desktop\Dataset Collections grey + coloured\COLOURFUL BASIC EMOTIONS Happy+Angray+Neutral+Sad PICTURES\Happy")) #happy face expression dataset file

# %%
#printing all image paths
imagePaths
# Out:
# ['C:\\Users\\Admin\\Desktop\\Dataset Collections grey + coloured\\COLOURFUL BASIC EMOTIONS Happy+Angray+Neutral+Sad PICTURES\\Happy\\000a72729218f928b4a9017cd09f71e30126ce497fe54446b94a90ea.JPG',
#  'C:\\Users\\Admin\\Desktop\\Dataset Collections grey + coloured\\COLOURFUL BASIC EMOTIONS Happy+Angray+Neutral+Sad PICTURES\\Happy\\000ad778e32e1c44f2ec87c991390e24e504de01d710fe9081aa0e75.jpg',
#  'C:\\Users\\Admin\\Desktop\\Dataset Collections grey + coloured\\COLOURFUL BASIC EMOTIONS Happy+Angray+Neutral+Sad PICTURES\\Happy\\000be90a828409ffe480ba9b3b8bab5fcad49c341a535dacb289d849.jpg',
#  'C:\\Users\\Admin\\Desktop\\Dataset Collections grey + coloured\\COLOURFUL BASIC EMOTIONS Happy+Angray+Neutral+Sad PICTURES\\Happy\\000ca24489f124e628370955605ca4e0112d2d18727cc0c9784ff5f1.jpg',
#  'C:\\Users\\Admin\\Desktop\\Dataset Collections grey + coloured\\COLOURFUL BASIC EMOTIONS Happy+Angray+Neutral+Sad PICTURES\\Happy\\002d58c033395fe86d8ec7959eba4233043c2b1ba004930686680808.jpg',
# ...

# %%
#displaying each image with openCV
for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    cv2.imshow("Frame", image)
    cv2.waitKey()
cv2.destroyAllWindows()
